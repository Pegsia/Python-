# %% [markdown]
# # 📚 3.2相恋篇-图像编码与解码

# %% [markdown]
# 在实际应用中，图像数据源格式多种多样，如：png\jpg\bmp等，而神经网络训练模型所需的图像的数据格式为：图像字节数据或Base64编码数据等。基于此，将png\jpg\bmp等格式的图像转换为字节数据的过程称为图像编码，将字节数据的图像转换为png\jpg\bmp等格式图像的过程称为图像解码。

# %% [markdown]
# ## 一、本节目标
#         本节将详述概述Tensorflow2中图像编码及解码的过程及实现。

# %% [markdown]
# ## 二、 图像编码
# Tensorflow图像编码的过程如下图所示，分为3个过程：转换为字节数据、转为网络安全Base64数据、标准Base64数据。接下来对这三个过程一一解析。
#
# 原始图像（png,jpg等）-> 字节数据 -> 网络安全Base64数据 -> 标准Base64数据

# %% [markdown]
# <img src="https://tianchi-public.oss-cn-hangzhou.aliyuncs.com/public/files/forum/161598423362436501615984232492.png"/>

# %% [markdown]
# ### 2.1 转换为字节数据
#      通俗的讲，png\jpg\bmp等格式的图像转换为字节数据就是图像读取。tensorflow常用的图像读取函数为：tf.io.read_file和tf.io.gfile.

# %%
import tensorflow as tf
image_path = 'tf_image/219.jpg'
image_bytes = tf.io.read_file(image_path)
print('图像的字节数据{}'.format(image_bytes)[:1000])
# Out:
# 图像的字节数据b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x01w\x01\xf4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\

# %% [markdown]
# ### 2.2 转为网络安全Base64编码
# 网络安全的base64编码数据使用“—”代替“+”，使用“—”代替“/”，以保证数据在网络传输过程中的正确性。

# %%
image_s64 = tf.io.encode_base64(image_bytes)
image_s64 = format(image_s64)[:1000]
print("网络安全的Base64编码：{}".format(image_s64))
# Out:
# 网络安全的Base64编码：b'_9j_4AAQSkZJRgABAQAAAQABAAD_2wBDAAIBAQEBAQIBAQECAgICAgQDAgICAgUEBAMEBgUGBgYFBgYGBwkIBgcJBwYGCAsICQoKCgoKBggLDAsKDAkKCgr_2wBDAQICAgICAgUDAwUKBwYHCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgoKCgr_wAARCAF3AfQDASIAAhEBAxEB_8QAHwAAAQUBAQEBAQEAAAAAAAAAAAECAwQFBgcICQoL_8QAtRAAAgEDAwIEAwUFBAQAAAF9AQIDAAQRBRIhMUEGE1FhByJxFDKBkaEII0KxwRVS0fAkM2JyggkKFhcYGRolJicoKSo0NTY3ODk6Q0RFRkdISUpTVFVWV1hZWmNkZWZnaGlqc3R1dnd4eXqDhIWGh4iJipKTlJWWl5iZmqKjpKWmp6ipqrKztLW2t7i5usLDxMXGx8jJytLT1NXW19jZ2uHi4-Tl5ufo6erx8vP09fb3-Pn6_8QAHwEAAwEBAQEBAQEBAQAAAAAAAAECAwQFBgcICQoL_8QAtREAAgECBAQDBAcFBAQAAQJ3AAECAxEEBSExBhJBUQdhcRMiMoEIFEKRobHBCSMzUvAVYnLRChYkNOEl8RcYGRomJygpKjU2Nzg5OkNERUZHSElKU1RVVldYWVpjZGVmZ2hpanN0dXZ3eHl6goOEhYaHiImKkpOUlZaXmJmaoqOkpaanqKmqsrO0tba3uLm6wsPExcbHyMnK0tPU1dbX2Nna4uPk5ebn6Onq8vP09fb3-Pn6_9oADAMBAAIRAxEAPwD5i8B3jLrVguoyxWugvqIub20W3MlteMrMBCUIbA3fMHB25LcruwecuvHuh2811pOpardW1xczz3FzLPP5s9pJKAW2FlVU3FwvlAbv4WyWWojZeN9csdITV5LbTdOhtxPvaf78eUM2w5blWkQMrfviGVVUArUvim00nW9Xg1

# %% [markdown]
# ### 4.1转为标准Base64编码：
# 标准的Base64数据中的“+”和“/”在网络中会被转换为“%XX”格式，而“%”在数据存储时必须进行转换。因此，标准Base64编码与网络安全的Base64编码之间的相互转换就是替换其中的不同之处即可。但是，需要注意的一点是：标准的Base64编码的数据大小是4的整数倍，不足的部分需要像卷积网络中的padding一样，用“=”补齐，已达到4的整数倍。

# %%
image_b64 = list(image_s64)
image_b64_lis = []
for i in range(len(image_b64)):
    if image_b64[i] == '-':
        image_b64_lis.append('+')
    elif image_b64[i] == '_':
        image_b64_lis.append('/')
    else:
        image_b64_lis.append(image_b64[i])

# 不足4倍数的使用=填充
if len(image_b64_lis) % 4 == 0:
    pass
else:
    remainder = len(image_b64_lis) % 4
    image_b64_lis.append('='*remainder)
image_b64 = "".join(image_b64_lis)
print("标准Base64编码：{}".format(image_b64)[:1000])
# Out:
# 标准Base64编码：b'...

# %% [markdown]
# ## 四、图像解码
# Tensorflow中图像解码的过程与图像编码的格式正好相反，如图所示。

# %% [markdown]
# <img src="https://tianchi-public.oss-cn-hangzhou.aliyuncs.com/public/files/forum/161598428397245751615984282798.png"/>

# %% [markdown]
# 在Tensorflow中，图像数据处理是基于图像矩阵数据进行的，因此解码过程需要将字节数据转换为矩阵数据。

# %% [markdown]
# ### 4.1 标准Base64解码转网络安全Base64数据

# %%
import tensorboard
import matplotlib.pyplot as plt
import tensorflow as tf
import base64
from tensorflow.keras import Sequential, layers, losses, optimizers, datasets
import datetime

image_path = 'tf_image/encode.jpg'
with open(image_path, 'rb') as f:
    image_data = f.read()
    # 图像文件编码为标准base64字节
    image_standard_b64_bytes = base64.b64encode(image_data)
    # 标准base64字节转换为字符串
    image_standard_b64_str = image_standard_b64_bytes.decode("utf8")
    # 标准base64字符串转为列表
    standard_b64_list = list(image_standard_b64_str)
    # 网络安全base64编码列表
    websafe_b64_list = []
    for i in range(len(standard_b64_list)):
        # /替换为_
        if standard_b64_list[i] == "/":
            websafe_b64_list.append("_")
        # +替换为-
        elif standard_b64_list[i] == "+":
            websafe_b64_list.append("-")
        # 剔除=
        elif standard_b64_list[i] == "=":
            break
        else:
            websafe_b64_list.append(standard_b64_list[i])
    # 网络安全base64列表转为字符串
    websafe_b64_str = "".join(websafe_b64_list)
web_b64_tensor = tf.convert_to_tensor(websafe_b64_str)
web_b64_decode = tf.io.decode_base64(web_b64_tensor)
image_matrix = tf.io.decode_image(web_b64_decode)
plt.imshow(image_matrix)
plt.show()

# %% [markdown]
# ### 4.3网络安全的Base64编码解码

# %%
image_path = 'tf_image/encode.jpg'
# 图像读取
image_bytes = tf.io.read_file(image_path) # 字节
image_b64 = tf.io.encode_base64(image_bytes) # 网络安全base64
image_b64 = tf.io.decode_base64(image_b64)
# image_matrix = tf.io.decode_image(image_b64)
# plt.imshow(image_matrix)
# plt.show()
# Out:
# tf.Tensor(b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xfe\x00>CREATOR: gd-jpeg v1.0 (using IJG JPEG v62), default quality\n\xff\xdb\x00C\x00\r\t\n\x0b\n\x08\r\x0b\n\x0b\x0e\x0e\r\x0f\x13 \x15\x13\x12\x12\x13\'\x1c\x1e\x17 .)10.)-,3:J>36F7,-@WAFLNRSR2>ZaZP`JQRO\xff\xdb\x00C\x01\x0e\x0e\x0e\x13\x11\x13&\x15\x15&O5-5OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO\xff\xc0\x00\x11\x08\x03\x0c\x04\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\xff\xc4\x00T\x10\x00\x01\x04\x01\x01\x05\x05\x06\x03\x04\x08\x03\x05\x06\x02\x0b\x01\x00\x02\x03\x11\x04!\x05\x121AQ\x13aq\x81\x91\x06\x14"\xa1\xb1\xd12R\xc1\x15#B\x92\x073CSb\x82\xe1\xf0$r\xf1\x164c\x83\x935DT\xa2\xb2\xc2\xd2%Us\x84\xc3\x17&\'Ed\xa3\xb3\xff\xc4\x00\x1a\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\xff\xc4\x00,\x11\x01\x01\x00\x02\x01\x04\x03\x00\x01\x04\x02\x03\x01\x01\x01\x00\x00\x01\x02\x11\x03\x12!1Q\x04\x13A\x14\x05"Ra\x15#2Bq\x81\x91\xa1\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf9\xe2\x10\x85\xe8r\x14\x9a\x10\xa8\x10\x84 \x02\x11HD\x08B\x104!\x08\nB\x13@"\x93B\x05I\xd2\x10\x80\xa4\xa94 \x10\x84R\x01\x1cP\x84\x02i&\x80B\x11H\x81\x08B\xa0B8&\x81!\x05\x16\x81\x82\x82\x80\x8bP\x16\x84$\x81\xa7I"\xd0>\tR\x10\x80B\x10\x81\xd2)+E\xda\x0105B\x10\x15h\xae\xe4\x03\xd50y Tx\xdaDuS\xba\xe0\x93\x80!]\n\xefT\xc0\xd5\x15\xaa\x90\x00\n\xa5\x04N\x89Zdj\xa3\xdc\x8a`\xa7}\xc9\x00\x98\x08\x00\x98I\x08\x89\x04\xc2@\x14\xc0*\x89\x0e\nA 4\xa5 \n2b\x92\xe6\x8a6\x8d\x00T=S\x06\xb4Q\x05H\xa0\x9d\xd8\x14\xa4\xd3Z\x15X%I\xa4\x13\xaa"\xc1v\xa6\x01\xae\n\x00\x8d5V\x02P\x14P\x01\x1cP\t%H\x1b\xe2\x106\x91z\xa9\xee\x824P\x00Z\xb0\r\x00\x08\x88\x91\xc9\x03\xa0R\xab)\x86\xf7*"/\xa2\x90\n@XL\rt\xe0\xa0\x1a\x15\x97\xa2\x88\x00\x950\xdd\x10 J\x90$\xa5\xb9AH4\xa0\x90\xd1H\x12\xa2\x06\x8am\x06\xd1\x13n\x81M\xa0\x92\xa2\x02\xb0\x0e\x08$\xd1\xc9X\x02\x88R\x148\xa8&\x02\x98\x14\x15{\xcaA\xd6\x82\xc6\xda\xb5\xa3\xaa\xa9\xa6\xb5S\x0e\xd5J\xab\xc1\xa5 U \xab\x01Ao\x04\xc1U\xdfza\xcahY\xbc\x98%V5S\x1e*\t\x03\xcc\x950z(\x01\xd4\xa9\x02\x02\x0b\x01?\xea\xa4\n\xac\x14\xf7\x82\x8a\xb490\xe2\xaa\xb0\x8d\xe4\x16\x87&\\\xa9.F\xf2\xba\x16\xef#z\xd5%\xc9\x17\xea\x9a\x17\xefRFEAqF\xf2\x86\xd7\x17\xf7\xa3{\xbdR]Io\xd2\r\x1b\xf4\x8d\xfbY\xf7\xd1\xbc\x83F\xf7z\x0b\xd6r\xfe\xf4\x17\xa0\xb8\xb9@\xb9T^\x91u\xf3Aa*\x04\xa8\xd9Q.\xaeh\x07\x15S\x9c\x87\xb9TJ\xa0q\xbej\xb7:\x93s\x95Nu*\x81\xceT<\xf5*Or\xa5\xeeTxd\xd0\x85\x1d\x82\x10\x8aU\x02\x13\xa4\xa9\x00\x9aT\x9a\x01\x08B\x02\x91I\xa1\x02M\x14\x9d \x10\x84 \x10\x84 )\t\xa1\x02Bt\x8a@\xa9\t\xa1\x02\t\xf2B\x10\x08B\x15Ah\xbd\x10\x84\x05\xa1\x14\x84\x02\x10\x8bP\x08\xb4Z\n\x00\xea\x10\x12M\x00\x80P\x9d\xa0\x10\x8bK\x92\x07H\xa4\x04\xf9 \x89Bi v\x8dRO\x92\x05\xaa-\x1c\xd4\xa9\x01`\xa2\xfb\xd2\xaa\xe0\x90\x04\x14\x12\xab\xe6\x83\xa2c\x86\xa9\x12\xa8D\xa4\x9e\x85%\x00\x98I0\x80\xa4\xe9\x00_\x05*W@\x01>\x08\x03\xa2|\xd1\x93\t\xdaC\x82z*\x02\xe4\x89\xbdS\xab)\xee\xdf\x04\x11\xb5&\x82\x0fra\xa0\rB/\x90@\x13\xc9\x00\x1b\xe0\x81\xc7U3\xa8\xd3\x8a\x06\xd0t\xd5X\t\xa5P\xbe\xaa\xd1\xc3\x8a%H\rT\xda,h\xa0/\x89V0\x9a\xbaA6\xb6\xc7\x05* \x05\x00\xe2\x02\x98\'K\xe0\xaa$XA\xe2\x98\x1dR\xde\xd6\xd4\xdam\x10\x80L4\xf4\xd1\x07Cv\xa4\r\x8d\n(`\x00\xf0VU\x9b\x01@\x11j\xd1\xc3D\xa8\x03I \x12\xa4[@$\xc2A\xe0\xa6\xf7\x05\x04@\xd5L\x01\xc5@\x12T\xc7\rR\x89\x82\xa6>j\xa0iL:\xd4U\x82\xba\xa7z\xaa\xed\x01\xc7\x86\xa9\xa4X\t\xae\n@\xaa\xc1\xeaT\x81\xb1\xa2\x0b\x9a\xed\x15\x8d\xb2\xa8i\xd5Z\r\xa0\xb9\xa5Kz\x95@\xd0\xd10l\xa8\xab\x81\xbej@\xaa\x81\xd5Ox\x00\x82a\xc4)\x02z\xaa\xb7\xfa)\x02\x82\xe0{\xd4\x83\x85*\x03\x93\x0eSB\xed\xe4\xf7\x95;\xc9\x83\xcd4-\x0eR\xde\xefUZE\xc3\xaa\x9a\x17ow\xa8\x97P\xe2\xaa.H\x92U\xd0\xb4\xba\xca`\xaa\x81\xa4o\xa9\xa1u\xa4M*\xb7\xd2/\xb4\xd0\xb0\xb9GxuU\x17\x12\x8bWB\xcd\xee\xf4o*\xf7\xab\x9a\x01%4\xab\x0b\x91\xbdj\x17I\x03\xaahOy\x05\xca6\xa2\\\x9a\x12.=T\x0b\x92.P&\xd16nr\xad\xceL\xe8\xa ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-e5e321837f72> in <module>
#       8 # plt.show()
#       9 print(image_b64)
# ---> 10 print(list(image_bytes)[:100])
#
# D:\Python3.8.0\lib\site-packages\tensorflow\python\framework\ops.py in __iter__(self)
#     524       raise TypeError("Cannot iterate over a tensor with unknown shape.")
#     525     if not shape:
# --> 526       raise TypeError("Cannot iterate over a scalar tensor.")
#     527     if shape[0] is None:
#     528       raise TypeError(
#
# TypeError: Cannot iterate over a scalar tensor.
